# %% [markdown]
# # Convolutional Neural Network in TensorFlow

# %%
import pandas as pd
import numpy as np
from sklearn.preprocessing import StandardScaler
from sklearn.cross_validation import train_test_split
data1 = pd.read_csv('./Nor96.csv', sep=",")
data2 = pd.read_csv('./Ab96.csv', sep=",")

data=data1.append(data2,ignore_index = True)

# %%
X = data[data.columns[0:27648]]

# %%
X = X.as_matrix().astype(np.float32)
scaler = StandardScaler()
X = scaler.fit_transform(X)

# %%
y = data[data.columns[27648:27650]]
y = y.as_matrix().astype(np.float32)

# %%
x_train, x_test, y_train, y_test = train_test_split(X, y, test_size=0.25, random_state=200)

# %%
import tensorflow as tf

# %%
# Parameters
learning_rate = 0.001
# learning_rate = 0.005
training_iters = 100000
batch_size = 21
display_step = 20

# %%
# Network Parameters
n_input = 27648 # MNIST data input (img shape: 28*28)
n_classes = 2 # MNIST total classes (0-2 digits)
dropout = 0.75 # Dropout, probability to keep units

# %%
# tf Graph input
x = tf.placeholder(tf.float32, [None, n_input])
y = tf.placeholder(tf.float32, [None, n_classes])
keep_prob = tf.placeholder(tf.float32) #dropout (keep probability)

# %%
# Create model
def conv2d(img, w, b):
    return tf.nn.relu(tf.nn.bias_add(tf.nn.conv2d(img, w, strides=[1, 1, 1, 1], 
                                                  padding='SAME'),b))

def max_pool(img, k):
    return tf.nn.max_pool(img, ksize=[1, k, k, 1], strides=[1, k, k, 1], padding='SAME')

def conv_net(_X, _weights, _biases, _dropout):
    # Reshape input picture
    _X = tf.reshape(_X, shape=[-1, 96, 96, 3])

    # Convolution Layer
    conv1 = conv2d(_X, _weights['wc1'], _biases['bc1'])
    # Max Pooling (down-sampling)
    conv1 = max_pool(conv1, k=2)
    # Apply Dropout
    conv1 = tf.nn.dropout(conv1, _dropout)

    # Convolution Layer
    conv2 = conv2d(conv1, _weights['wc2'], _biases['bc2'])
    # Max Pooling (down-sampling)
    conv2 = max_pool(conv2, k=2)
    # Apply Dropout
    conv2 = tf.nn.dropout(conv2, _dropout)
    
    # Convolution Layer
    conv3 = conv2d(conv2, _weights['wc3'], _biases['bc3'])
    # Max Pooling (down-sampling)
    conv3 = max_pool(conv3, k=2)
    # Apply Dropout
    conv3 = tf.nn.dropout(conv3, _dropout)
    
    # Convolution Layer
    conv4 = conv2d(conv3, _weights['wc4'], _biases['bc4'])
    # Max Pooling (down-sampling)
    conv4 = max_pool(conv4, k=2)
    # Apply Dropout
    conv4 = tf.nn.dropout(conv4, _dropout)

    # Convolution Layer
    conv5 = conv2d(conv4, _weights['wc5'], _biases['bc5'])
    # Max Pooling (down-sampling)
    conv5 = max_pool(conv5, k=2)
    # Apply Dropout
    conv5 = tf.nn.dropout(conv5, _dropout)

    # Fully connected layer
    # Reshape conv2 output to fit dense layer input
    dense1 = tf.reshape(conv5, [-1, _weights['wd1'].get_shape().as_list()[0]]) 
    # Relu activation
    dense1 = tf.nn.relu(tf.add(tf.matmul(dense1, _weights['wd1']), _biases['bd1']))
    # Apply Dropout
    dense1 = tf.nn.dropout(dense1, _dropout) # Apply Dropout

    # Output, class prediction
    out = tf.add(tf.matmul(dense1, _weights['out']), _biases['out'])
    return out

# %%
# Store layers weight & bias
weights = {
    # 5x5 conv, 1 input, 32 outputs
    'wc1': tf.Variable(tf.random_normal([5, 5, 3, 96])), 
    # 5x5 conv, 32 inputs, 64 outputs
    'wc2': tf.Variable(tf.random_normal([5, 5, 96, 192])), 
    'wc3': tf.Variable(tf.random_normal([5, 5, 192, 384])), 
    'wc4': tf.Variable(tf.random_normal([5, 5, 384, 768])), 
    'wc5': tf.Variable(tf.random_normal([5, 5, 768, 1536])), 
    

    # fully connected, 7*7*64 inputs, 1024 outputs
    'wd1': tf.Variable(tf.random_normal([3*3*1536, 3072])), 
    # 1024 inputs, 2 outputs (class prediction)
    'out': tf.Variable(tf.random_normal([3072, n_classes])) 
}

biases = {
    'bc1': tf.Variable(tf.random_normal([96])),
    'bc2': tf.Variable(tf.random_normal([192])),
    'bc3': tf.Variable(tf.random_normal([384])),
    'bc4': tf.Variable(tf.random_normal([768])),
    'bc5': tf.Variable(tf.random_normal([1536])),
    'bd1': tf.Variable(tf.random_normal([3072])),
    'out': tf.Variable(tf.random_normal([n_classes]))
}

# %%
# Construct model
pred = conv_net(x, weights, biases, keep_prob)

# %%
# Define loss and optimizer
cost = tf.reduce_mean(tf.nn.softmax_cross_entropy_with_logits(pred, y))
optimizer = tf.train.AdamOptimizer(learning_rate=learning_rate).minimize(cost)

# %%
# Evaluate model
correct_pred = tf.equal(tf.argmax(pred,1), tf.argmax(y,1))
accuracy = tf.reduce_mean(tf.cast(correct_pred, tf.float32))

# %%
# Initializing the variables
init = tf.initialize_all_variables()

# %%
def batch_gen(X, y, N):
    while True:
        idx = np.random.choice(len(y), N)
        yield X[idx].astype('float32'), y[idx].astype('float32')

# %%
# Launch the graph
with tf.Session() as sess:
    sess.run(init)
    step = 1
    # Keep training until reach max iterations
    while step * batch_size < training_iters:        
        train_batches = batch_gen(x_train, y_train, batch_size)
        batch_xs, batch_ys = next(train_batches)
        # Fit training using batch data
        sess.run(optimizer, feed_dict={x: batch_xs, y: batch_ys, keep_prob: dropout})
        if step % display_step == 0:
            # Calculate batch accuracy
            acc = sess.run(accuracy, feed_dict={x: batch_xs, y: batch_ys, keep_prob: 1.})
            # Calculate batch loss
            loss = sess.run(cost, feed_dict={x: batch_xs, y: batch_ys, keep_prob: 1.})
            print ("Iter " + str(step*batch_size) + ", Minibatch Loss= " + \
                  "{:.6f}".format(loss) + ", Training Accuracy= " + \
                "{:.5f}".format(acc))
            print ("Testing Accuracy:", sess.run(accuracy, feed_dict={x: x_test, 
                                                             y: y_test, 
                                                             keep_prob: 1.}))
        step += 1
# Out:
# Iter 420, Minibatch Loss= 236605931520.000000, Training Accuracy= 0.57143
# ('Testing Accuracy:', 0.52380955)
# Iter 840, Minibatch Loss= 103199236096.000000, Training Accuracy= 0.61905
# ('Testing Accuracy:', 0.61904764)
# Iter 1260, Minibatch Loss= 54280499200.000000, Training Accuracy= 0.71429
# ('Testing Accuracy:', 0.78571427)
# Iter 1680, Minibatch Loss= 33481218048.000000, Training Accuracy= 0.85714
# ('Testing Accuracy:', 0.73809522)
# Iter 2100, Minibatch Loss= 82700075008.000000, Training Accuracy= 0.57143
# ('Testing Accuracy:', 0.66666669)
# Iter 2520, Minibatch Loss= 61095710720.000000, Training Accuracy= 0.71429
# ('Testing Accuracy:', 0.61904764)
# Iter 2940, Minibatch Loss= 10636358656.000000, Training Accuracy= 0.95238
# ('Testing Accuracy:', 0.76190478)
# Iter 3360, Minibatch Loss= 8196267520.000000, Training Accuracy= 0.90476
# ('Testing Accuracy:', 0.78571427)
# Iter 3780, Minibatch Loss= 15503820800.000000, Training Accuracy= 0.90476
# ('Testing Accuracy:', 0.83333331)
# Iter 4200, Minibatch Loss= 30409525248.000000, Training Accuracy= 0.85714
# ('Testing Accuracy:', 0.76190478)
# Iter 4620, Minibatch Loss= 46097453056.000000, Training Accuracy= 0.71429
# ('Testing Accuracy:', 0.61904764)
# Iter 5040, Minibatch Loss= 54025945088.000000, Training Accuracy= 0.66667
# ('Testing Accuracy:', 0.71428573)
# Iter 5460, Minibatch Loss= 47159996416.000000, Training Accuracy= 0.66667
# ('Testing Accuracy:', 0.71428573)
# Iter 5880, Minibatch Loss= 11722957824.000000, Training Accuracy= 0.95238
# ('Testing Accuracy:', 0.85714287)
# Iter 6300, Minibatch Loss= 13175468032.000000, Training Accuracy= 0.90476
# ('Testing Accuracy:', 0.85714287)
# Iter 6720, Minibatch Loss= 3029464064.000000, Training Accuracy= 0.95238
# ('Testing Accuracy:', 0.80952382)
# Iter 7140, Minibatch Loss= 15495749632.000000, Training Accuracy= 0.90476
# ('Testing Accuracy:', 0.73809522)
# Iter 7560, Minibatch Loss= 5047100416.000000, Training Accuracy= 0.90476
# ('Testing Accuracy:', 0.78571427)
# Iter 7980, Minibatch Loss= 16013381632.000000, Training Accuracy= 0.90476
# ('Testing Accuracy:', 0.80952382)
# Iter 8400, Minibatch Loss= 41828700160.000000, Training Accuracy= 0.80952
# ('Testing Accuracy:', 0.71428573)
# Iter 8820, Minibatch Loss= 10510469120.000000, Training Accuracy= 0.85714
# ('Testing Accuracy:', 0.64285713)
# Iter 9240, Minibatch Loss= 21094436864.000000, Training Accuracy= 0.80952
# ('Testing Accuracy:', 0.76190478)
# Iter 9660, Minibatch Loss= 7005317632.000000, Training Accuracy= 0.90476
# ('Testing Accuracy:', 0.78571427)
# Iter 10080, Minibatch Loss= 19232749568.000000, Training Accuracy= 0.76190
# ('Testing Accuracy:', 0.66666669)
# Iter 10500, Minibatch Loss= 23023421440.000000, Training Accuracy= 0.76190
# ('Testing Accuracy:', 0.64285713)
# Iter 10920, Minibatch Loss= 11034542080.000000, Training Accuracy= 0.85714
# ('Testing Accuracy:', 0.78571427)
# Iter 11340, Minibatch Loss= 25295175680.000000, Training Accuracy= 0.76190
# ('Testing Accuracy:', 0.69047618)
# Iter 11760, Minibatch Loss= 23422013440.000000, Training Accuracy= 0.76190
# ('Testing Accuracy:', 0.69047618)
# Iter 12180, Minibatch Loss= 42462179328.000000, Training Accuracy= 0.61905
# ('Testing Accuracy:', 0.66666669)
# Iter 12600, Minibatch Loss= 5167566848.000000, Training Accuracy= 0.95238
# ('Testing Accuracy:', 0.71428573)
# Iter 13020, Minibatch Loss= 19575488512.000000, Training Accuracy= 0.90476
# ('Testing Accuracy:', 0.61904764)
# Iter 13440, Minibatch Loss= 632852672.000000, Training Accuracy= 0.95238
# ('Testing Accuracy:', 0.80952382)
# Iter 13860, Minibatch Loss= 37739999232.000000, Training Accuracy= 0.61905
# ('Testing Accuracy:', 0.5714286)
# Iter 14280, Minibatch Loss= 4348688896.000000, Training Accuracy= 0.90476
# ('Testing Accuracy:', 0.83333331)
# Iter 14700, Minibatch Loss= 8263515136.000000, Training Accuracy= 0.90476
# ('Testing Accuracy:', 0.61904764)
# Iter 15120, Minibatch Loss= 12123099136.000000, Training Accuracy= 0.85714
# ('Testing Accuracy:', 0.64285713)
# Iter 15540, Minibatch Loss= 727494080.000000, Training Accuracy= 0.95238
# ('Testing Accuracy:', 0.76190478)
# Iter 15960, Minibatch Loss= 6960814080.000000, Training Accuracy= 0.90476
# ('Testing Accuracy:', 0.71428573)
# Iter 16380, Minibatch Loss= 12870121472.000000, Training Accuracy= 0.90476
# ('Testing Accuracy:', 0.71428573)
# Iter 16800, Minibatch Loss= 25715664896.000000, Training Accuracy= 0.76190
# ('Testing Accuracy:', 0.64285713)
# Iter 17220, Minibatch Loss= 9473965056.000000, Training Accuracy= 0.85714
# ('Testing Accuracy:', 0.76190478)
# Iter 17640, Minibatch Loss= 28888356864.000000, Training Accuracy= 0.76190
# ('Testing Accuracy:', 0.64285713)
# Iter 18060, Minibatch Loss= 0.000000, Training Accuracy= 1.00000
# ('Testing Accuracy:', 0.78571427)
# Iter 18480, Minibatch Loss= 5432365568.000000, Training Accuracy= 0.90476
# ('Testing Accuracy:', 0.78571427)
# Iter 18900, Minibatch Loss= 8814773248.000000, Training Accuracy= 0.90476
# ('Testing Accuracy:', 0.73809522)
# Iter 19320, Minibatch Loss= 19893329920.000000, Training Accuracy= 0.76190
# ('Testing Accuracy:', 0.76190478)
# Iter 19740, Minibatch Loss= 4784400384.000000, Training Accuracy= 0.90476
# ('Testing Accuracy:', 0.69047618)
# Iter 20160, Minibatch Loss= 15193488384.000000, Training Accuracy= 0.80952
# ('Testing Accuracy:', 0.73809522)
# Iter 20580, Minibatch Loss= 16984793088.000000, Training Accuracy= 0.76190
# ('Testing Accuracy:', 0.73809522)
# Iter 21000, Minibatch Loss= 11503167488.000000, Training Accuracy= 0.76190
# ('Testing Accuracy:', 0.71428573)
# Iter 21420, Minibatch Loss= 6921932800.000000, Training Accuracy= 0.90476
# ('Testing Accuracy:', 0.76190478)
# Iter 21840, Minibatch Loss= 4500360704.000000, Training Accuracy= 0.80952
# ('Testing Accuracy:', 0.61904764)
# Iter 22260, Minibatch Loss= 7861684736.000000, Training Accuracy= 0.90476
# ('Testing Accuracy:', 0.73809522)
# Iter 22680, Minibatch Loss= 9353151488.000000, Training Accuracy= 0.85714
# ('Testing Accuracy:', 0.69047618)
# Iter 23100, Minibatch Loss= 21546711040.000000, Training Accuracy= 0.71429
# ('Testing Accuracy:', 0.61904764)
# Iter 23520, Minibatch Loss= 7147712000.000000, Training Accuracy= 0.90476
# ('Testing Accuracy:', 0.69047618)
# Iter 23940, Minibatch Loss= 13646028800.000000, Training Accuracy= 0.80952
# ('Testing Accuracy:', 0.61904764)
# Iter 24360, Minibatch Loss= 0.000000, Training Accuracy= 1.00000
# ('Testing Accuracy:', 0.78571427)
# Iter 24780, Minibatch Loss= 17735118848.000000, Training Accuracy= 0.80952
# ('Testing Accuracy:', 0.64285713)
# Iter 25200, Minibatch Loss= 5853811712.000000, Training Accuracy= 0.85714
# ('Testing Accuracy:', 0.64285713)
# Iter 25620, Minibatch Loss= 3783774720.000000, Training Accuracy= 0.95238
# ('Testing Accuracy:', 0.83333331)
# Iter 26040, Minibatch Loss= 640056448.000000, Training Accuracy= 0.95238
# ('Testing Accuracy:', 0.69047618)
# Iter 26460, Minibatch Loss= 0.000000, Training Accuracy= 1.00000
# ('Testing Accuracy:', 0.80952382)
# Iter 26880, Minibatch Loss= 0.000000, Training Accuracy= 1.00000
# ('Testing Accuracy:', 0.80952382)
# Iter 27300, Minibatch Loss= 4969474560.000000, Training Accuracy= 0.90476
# ('Testing Accuracy:', 0.69047618)
# Iter 27720, Minibatch Loss= 348938976.000000, Training Accuracy= 0.95238
# ('Testing Accuracy:', 0.80952382)
# Iter 28140, Minibatch Loss= 5713223680.000000, Training Accuracy= 0.90476
# ('Testing Accuracy:', 0.64285713)
# Iter 28560, Minibatch Loss= 2317232128.000000, Training Accuracy= 0.90476
# ('Testing Accuracy:', 0.69047618)
# Iter 28980, Minibatch Loss= 8419691520.000000, Training Accuracy= 0.80952
# ('Testing Accuracy:', 0.66666669)
# Iter 29400, Minibatch Loss= 1046049536.000000, Training Accuracy= 0.95238
# ('Testing Accuracy:', 0.80952382)
# Iter 29820, Minibatch Loss= 398820704.000000, Training Accuracy= 0.95238
# ('Testing Accuracy:', 0.78571427)
# Iter 30240, Minibatch Loss= 771174016.000000, Training Accuracy= 0.95238
# ('Testing Accuracy:', 0.80952382)
# Iter 30660, Minibatch Loss= 0.000000, Training Accuracy= 1.00000
# ('Testing Accuracy:', 0.73809522)
# Iter 31080, Minibatch Loss= 942937792.000000, Training Accuracy= 0.95238
# ('Testing Accuracy:', 0.80952382)
# Iter 31500, Minibatch Loss= 1984252928.000000, Training Accuracy= 0.95238
# ('Testing Accuracy:', 0.76190478)
# Iter 31920, Minibatch Loss= 19100078080.000000, Training Accuracy= 0.76190
# ('Testing Accuracy:', 0.66666669)
# Iter 32340, Minibatch Loss= 0.000000, Training Accuracy= 1.00000
# ('Testing Accuracy:', 0.78571427)
# Iter 32760, Minibatch Loss= 7175514112.000000, Training Accuracy= 0.90476
# ('Testing Accuracy:', 0.64285713)
# Iter 33180, Minibatch Loss= 2775341824.000000, Training Accuracy= 0.95238
# ('Testing Accuracy:', 0.76190478)
# Iter 33600, Minibatch Loss= 1333583616.000000, Training Accuracy= 0.95238
# ('Testing Accuracy:', 0.80952382)
# Iter 34020, Minibatch Loss= 2447622656.000000, Training Accuracy= 0.90476
# ('Testing Accuracy:', 0.69047618)
# Iter 34440, Minibatch Loss= 0.000000, Training Accuracy= 1.00000
# ('Testing Accuracy:', 0.83333331)
# Iter 34860, Minibatch Loss= 5239877632.000000, Training Accuracy= 0.90476
# ('Testing Accuracy:', 0.76190478)
# Iter 35280, Minibatch Loss= 0.000000, Training Accuracy= 1.00000
# ('Testing Accuracy:', 0.73809522)
# Iter 35700, Minibatch Loss= 2078560640.000000, Training Accuracy= 0.95238
# ('Testing Accuracy:', 0.71428573)
# Iter 36120, Minibatch Loss= 2338819840.000000, Training Accuracy= 0.95238
# ('Testing Accuracy:', 0.80952382)
# Iter 36540, Minibatch Loss= 20623003648.000000, Training Accuracy= 0.61905
# ('Testing Accuracy:', 0.66666669)
# Iter 36960, Minibatch Loss= 4934945280.000000, Training Accuracy= 0.90476
# ('Testing Accuracy:', 0.66666669)
# Iter 37380, Minibatch Loss= 9903101952.000000, Training Accuracy= 0.85714
# ('Testing Accuracy:', 0.66666669)
# Iter 37800, Minibatch Loss= 5864454144.000000, Training Accuracy= 0.90476
# ('Testing Accuracy:', 0.69047618)
# Iter 38220, Minibatch Loss= 0.000000, Training Accuracy= 1.00000
# ('Testing Accuracy:', 0.83333331)
# Iter 38640, Minibatch Loss= 0.000000, Training Accuracy= 1.00000
# ('Testing Accuracy:', 0.80952382)
# Iter 39060, Minibatch Loss= 5288240128.000000, Training Accuracy= 0.76190
# ('Testing Accuracy:', 0.66666669)
# Iter 39480, Minibatch Loss= 1617961216.000000, Training Accuracy= 0.95238
# ('Testing Accuracy:', 0.85714287)
# Iter 39900, Minibatch Loss= 0.000000, Training Accuracy= 1.00000
# ('Testing Accuracy:', 0.88095236)
# Iter 40320, Minibatch Loss= 493900160.000000, Training Accuracy= 0.95238
# ('Testing Accuracy:', 0.73809522)
# Iter 40740, Minibatch Loss= 4047539712.000000, Training Accuracy= 0.95238
# ('Testing Accuracy:', 0.85714287)
# Iter 41160, Minibatch Loss= 5584429568.000000, Training Accuracy= 0.95238
# ('Testing Accuracy:', 0.69047618)
# Iter 41580, Minibatch Loss= 1190223488.000000, Training Accuracy= 0.95238
# ('Testing Accuracy:', 0.76190478)
# Iter 42000, Minibatch Loss= 0.000000, Training Accuracy= 1.00000
# ('Testing Accuracy:', 0.88095236)
# Iter 42420, Minibatch Loss= 0.000000, Training Accuracy= 1.00000
# ('Testing Accuracy:', 0.88095236)
# Iter 42840, Minibatch Loss= 0.000000, Training Accuracy= 1.00000
# ('Testing Accuracy:', 0.83333331)
# Iter 43260, Minibatch Loss= 0.000000, Training Accuracy= 1.00000
# ('Testing Accuracy:', 0.83333331)
# Iter 43680, Minibatch Loss= 0.000000, Training Accuracy= 1.00000
# ('Testing Accuracy:', 0.78571427)
# Iter 44100, Minibatch Loss= 2340227840.000000, Training Accuracy= 0.95238
# ('Testing Accuracy:', 0.80952382)
# Iter 44520, Minibatch Loss= 3023196928.000000, Training Accuracy= 0.90476
# ('Testing Accuracy:', 0.78571427)
# Iter 44940, Minibatch Loss= 0.000000, Training Accuracy= 1.00000
# ('Testing Accuracy:', 0.66666669)
# Iter 45360, Minibatch Loss= 0.000000, Training Accuracy= 1.00000
# ('Testing Accuracy:', 0.78571427)
# Iter 45780, Minibatch Loss= 0.000000, Training Accuracy= 1.00000
# ('Testing Accuracy:', 0.83333331)
# Iter 46200, Minibatch Loss= 0.000000, Training Accuracy= 1.00000
# ('Testing Accuracy:', 0.80952382)
# Iter 46620, Minibatch Loss= 0.000000, Training Accuracy= 1.00000
# ('Testing Accuracy:', 0.78571427)
# Iter 47040, Minibatch Loss= 1434591488.000000, Training Accuracy= 0.95238
# ('Testing Accuracy:', 0.83333331)
# Iter 47460, Minibatch Loss= 246448320.000000, Training Accuracy= 0.95238
# ('Testing Accuracy:', 0.85714287)
# Iter 47880, Minibatch Loss= 1724595072.000000, Training Accuracy= 0.90476
# ('Testing Accuracy:', 0.76190478)
# Iter 48300, Minibatch Loss= 845278080.000000, Training Accuracy= 0.95238
# ('Testing Accuracy:', 0.69047618)
# Iter 48720, Minibatch Loss= 2923974400.000000, Training Accuracy= 0.80952
# ('Testing Accuracy:', 0.80952382)
# Iter 49140, Minibatch Loss= 239124480.000000, Training Accuracy= 0.95238
# ('Testing Accuracy:', 0.83333331)
# Iter 49560, Minibatch Loss= 212526624.000000, Training Accuracy= 0.95238
# ('Testing Accuracy:', 0.71428573)
# Iter 49980, Minibatch Loss= 1988730112.000000, Training Accuracy= 0.90476
# ('Testing Accuracy:', 0.76190478)
# Iter 50400, Minibatch Loss= 0.000000, Training Accuracy= 1.00000
# ('Testing Accuracy:', 0.83333331)
# Iter 50820, Minibatch Loss= 2388505600.000000, Training Accuracy= 0.95238
# ('Testing Accuracy:', 0.71428573)
# Iter 51240, Minibatch Loss= 2570848256.000000, Training Accuracy= 0.80952
# ('Testing Accuracy:', 0.66666669)
# Iter 51660, Minibatch Loss= 0.000000, Training Accuracy= 1.00000
# ('Testing Accuracy:', 0.83333331)
# Iter 52080, Minibatch Loss= 2734452992.000000, Training Accuracy= 0.80952
# ('Testing Accuracy:', 0.69047618)
# Iter 52500, Minibatch Loss= 2036460160.000000, Training Accuracy= 0.90476
# ('Testing Accuracy:', 0.66666669)
# Iter 52920, Minibatch Loss= 0.000000, Training Accuracy= 1.00000
# ('Testing Accuracy:', 0.80952382)
# Iter 53340, Minibatch Loss= 1309057024.000000, Training Accuracy= 0.95238
# ('Testing Accuracy:', 0.66666669)
# Iter 53760, Minibatch Loss= 0.000000, Training Accuracy= 1.00000
# ('Testing Accuracy:', 0.76190478)
# Iter 54180, Minibatch Loss= 2494225408.000000, Training Accuracy= 0.95238
# ('Testing Accuracy:', 0.76190478)
# Iter 54600, Minibatch Loss= 437621696.000000, Training Accuracy= 0.95238
# ('Testing Accuracy:', 0.73809522)
# Iter 55020, Minibatch Loss= 960571584.000000, Training Accuracy= 0.95238
# ('Testing Accuracy:', 0.78571427)
# Iter 55440, Minibatch Loss= 2219141120.000000, Training Accuracy= 0.95238
# ('Testing Accuracy:', 0.71428573)
# Iter 55860, Minibatch Loss= 4595980288.000000, Training Accuracy= 0.80952
# ('Testing Accuracy:', 0.66666669)
# Iter 56280, Minibatch Loss= 0.000000, Training Accuracy= 1.00000
# ('Testing Accuracy:', 0.73809522)
# Iter 56700, Minibatch Loss= 0.000000, Training Accuracy= 1.00000
# ('Testing Accuracy:', 0.76190478)
# Iter 57120, Minibatch Loss= 2281584384.000000, Training Accuracy= 0.90476
# ('Testing Accuracy:', 0.78571427)
# Iter 57540, Minibatch Loss= 0.000000, Training Accuracy= 1.00000
# ('Testing Accuracy:', 0.78571427)
# Iter 57960, Minibatch Loss= 266168800.000000, Training Accuracy= 0.95238
# ('Testing Accuracy:', 0.66666669)
# Iter 58380, Minibatch Loss= 0.000000, Training Accuracy= 1.00000
# ('Testing Accuracy:', 0.73809522)
# Iter 58800, Minibatch Loss= 2005827840.000000, Training Accuracy= 0.95238
# ('Testing Accuracy:', 0.76190478)
# Iter 59220, Minibatch Loss= 1003543232.000000, Training Accuracy= 0.95238
# ('Testing Accuracy:', 0.71428573)
# Iter 59640, Minibatch Loss= 1044912000.000000, Training Accuracy= 0.95238
# ('Testing Accuracy:', 0.80952382)
# Iter 60060, Minibatch Loss= 0.000000, Training Accuracy= 1.00000
# ('Testing Accuracy:', 0.80952382)
# Iter 60480, Minibatch Loss= 924665344.000000, Training Accuracy= 0.95238
# ('Testing Accuracy:', 0.73809522)
# Iter 60900, Minibatch Loss= 0.000000, Training Accuracy= 1.00000
# ('Testing Accuracy:', 0.66666669)
# Iter 61320, Minibatch Loss= 74196112.000000, Training Accuracy= 0.95238
# ('Testing Accuracy:', 0.66666669)
# Iter 61740, Minibatch Loss= 1680863872.000000, Training Accuracy= 0.90476
# ('Testing Accuracy:', 0.71428573)
# Iter 62160, Minibatch Loss= 4010795776.000000, Training Accuracy= 0.85714
# ('Testing Accuracy:', 0.64285713)
# Iter 62580, Minibatch Loss= 0.000000, Training Accuracy= 1.00000
# ('Testing Accuracy:', 0.85714287)
# Iter 63000, Minibatch Loss= 0.000000, Training Accuracy= 1.00000
# ('Testing Accuracy:', 0.80952382)
# Iter 63420, Minibatch Loss= 0.000000, Training Accuracy= 1.00000
# ('Testing Accuracy:', 0.88095236)
# Iter 63840, Minibatch Loss= 0.000000, Training Accuracy= 1.00000
# ('Testing Accuracy:', 0.80952382)
# Iter 64260, Minibatch Loss= 1643849216.000000, Training Accuracy= 0.95238
# ('Testing Accuracy:', 0.71428573)
# Iter 64680, Minibatch Loss= 1449192832.000000, Training Accuracy= 0.95238
# ('Testing Accuracy:', 0.76190478)
# Iter 65100, Minibatch Loss= 2162322176.000000, Training Accuracy= 0.95238
# ('Testing Accuracy:', 0.78571427)
# Iter 65520, Minibatch Loss= 0.000000, Training Accuracy= 1.00000
# ('Testing Accuracy:', 0.78571427)
# Iter 65940, Minibatch Loss= 0.000000, Training Accuracy= 1.00000
# ('Testing Accuracy:', 0.80952382)
# Iter 66360, Minibatch Loss= 0.000000, Training Accuracy= 1.00000
# ('Testing Accuracy:', 0.80952382)
# Iter 66780, Minibatch Loss= 0.000000, Training Accuracy= 1.00000
# ('Testing Accuracy:', 0.71428573)
# Iter 67200, Minibatch Loss= 0.000000, Training Accuracy= 1.00000
# ('Testing Accuracy:', 0.85714287)
# Iter 67620, Minibatch Loss= 542232384.000000, Training Accuracy= 0.95238
# ('Testing Accuracy:', 0.69047618)
# Iter 68040, Minibatch Loss= 1618440832.000000, Training Accuracy= 0.95238
# ('Testing Accuracy:', 0.73809522)
# Iter 68460, Minibatch Loss= 0.000000, Training Accuracy= 1.00000
# ('Testing Accuracy:', 0.76190478)
# Iter 68880, Minibatch Loss= 676104896.000000, Training Accuracy= 0.95238
# ('Testing Accuracy:', 0.73809522)
# Iter 69300, Minibatch Loss= 3516098560.000000, Training Accuracy= 0.85714
# ('Testing Accuracy:', 0.69047618)
# Iter 69720, Minibatch Loss= 0.000000, Training Accuracy= 1.00000
# ('Testing Accuracy:', 0.85714287)
# Iter 70140, Minibatch Loss= 4938969088.000000, Training Accuracy= 0.90476
# ('Testing Accuracy:', 0.66666669)
# Iter 70560, Minibatch Loss= 1299290112.000000, Training Accuracy= 0.95238
# ('Testing Accuracy:', 0.73809522)
# Iter 70980, Minibatch Loss= 1398000512.000000, Training Accuracy= 0.90476
# ('Testing Accuracy:', 0.69047618)
# Iter 71400, Minibatch Loss= 0.000000, Training Accuracy= 1.00000
# ('Testing Accuracy:', 0.88095236)
# Iter 71820, Minibatch Loss= 0.000000, Training Accuracy= 1.00000
# ('Testing Accuracy:', 0.73809522)
# Iter 72240, Minibatch Loss= 0.000000, Training Accuracy= 1.00000
# ('Testing Accuracy:', 0.80952382)
# Iter 72660, Minibatch Loss= 1677616512.000000, Training Accuracy= 0.80952
# ('Testing Accuracy:', 0.69047618)
# Iter 73080, Minibatch Loss= 0.000000, Training Accuracy= 1.00000
# ('Testing Accuracy:', 0.83333331)
# Iter 73500, Minibatch Loss= 0.000000, Training Accuracy= 1.00000
# ('Testing Accuracy:', 0.83333331)
# Iter 73920, Minibatch Loss= 0.000000, Training Accuracy= 1.00000
# ('Testing Accuracy:', 0.83333331)
# Iter 74340, Minibatch Loss= 0.000000, Training Accuracy= 1.00000
# ('Testing Accuracy:', 0.80952382)
# Iter 74760, Minibatch Loss= 0.000000, Training Accuracy= 1.00000
# ('Testing Accuracy:', 0.80952382)
# Iter 75180, Minibatch Loss= 2915806976.000000, Training Accuracy= 0.90476
# ('Testing Accuracy:', 0.69047618)
# Iter 75600, Minibatch Loss= 0.000000, Training Accuracy= 1.00000
# ('Testing Accuracy:', 0.83333331)
# Iter 76020, Minibatch Loss= 0.000000, Training Accuracy= 1.00000
# ('Testing Accuracy:', 0.83333331)
# Iter 76440, Minibatch Loss= 1851461632.000000, Training Accuracy= 0.95238
# ('Testing Accuracy:', 0.73809522)
# Iter 76860, Minibatch Loss= 0.000000, Training Accuracy= 1.00000
# ('Testing Accuracy:', 0.83333331)
# Iter 77280, Minibatch Loss= 0.000000, Training Accuracy= 1.00000
# ('Testing Accuracy:', 0.78571427)
# Iter 77700, Minibatch Loss= 0.000000, Training Accuracy= 1.00000
# ('Testing Accuracy:', 0.80952382)
# Iter 78120, Minibatch Loss= 0.000000, Training Accuracy= 1.00000
# ('Testing Accuracy:', 0.88095236)
# Iter 78540, Minibatch Loss= 0.000000, Training Accuracy= 1.00000
# ('Testing Accuracy:', 0.83333331)
# Iter 78960, Minibatch Loss= 0.000000, Training Accuracy= 1.00000
# ('Testing Accuracy:', 0.85714287)
# Iter 79380, Minibatch Loss= 0.000000, Training Accuracy= 1.00000
# ('Testing Accuracy:', 0.80952382)
# Iter 79800, Minibatch Loss= 0.000000, Training Accuracy= 1.00000
# ('Testing Accuracy:', 0.88095236)
# Iter 80220, Minibatch Loss= 0.000000, Training Accuracy= 1.00000
# ('Testing Accuracy:', 0.78571427)
# Iter 80640, Minibatch Loss= 0.000000, Training Accuracy= 1.00000
# ('Testing Accuracy:', 0.80952382)
# Iter 81060, Minibatch Loss= 0.000000, Training Accuracy= 1.00000
# ('Testing Accuracy:', 0.78571427)
# Iter 81480, Minibatch Loss= 0.000000, Training Accuracy= 1.00000
# ('Testing Accuracy:', 0.88095236)
# Iter 81900, Minibatch Loss= 0.000000, Training Accuracy= 1.00000
# ('Testing Accuracy:', 0.88095236)
# Iter 82320, Minibatch Loss= 0.000000, Training Accuracy= 1.00000
# ('Testing Accuracy:', 0.88095236)
# Iter 82740, Minibatch Loss= 0.000000, Training Accuracy= 1.00000
# ('Testing Accuracy:', 0.85714287)
# Iter 83160, Minibatch Loss= 0.000000, Training Accuracy= 1.00000
# ('Testing Accuracy:', 0.88095236)
# Iter 83580, Minibatch Loss= 0.000000, Training Accuracy= 1.00000
# ('Testing Accuracy:', 0.88095236)
# Iter 84000, Minibatch Loss= 0.000000, Training Accuracy= 1.00000
# ('Testing Accuracy:', 0.88095236)
# Iter 84420, Minibatch Loss= 0.000000, Training Accuracy= 1.00000
# ('Testing Accuracy:', 0.85714287)
# Iter 84840, Minibatch Loss= 1265109248.000000, Training Accuracy= 0.95238
# ('Testing Accuracy:', 0.85714287)
# Iter 85260, Minibatch Loss= 0.000000, Training Accuracy= 1.00000
# ('Testing Accuracy:', 0.85714287)
# Iter 85680, Minibatch Loss= 0.000000, Training Accuracy= 1.00000
# ('Testing Accuracy:', 0.88095236)
# Iter 86100, Minibatch Loss= 0.000000, Training Accuracy= 1.00000
# ('Testing Accuracy:', 0.73809522)
# Iter 86520, Minibatch Loss= 0.000000, Training Accuracy= 1.00000
# ('Testing Accuracy:', 0.88095236)
# Iter 86940, Minibatch Loss= 0.000000, Training Accuracy= 1.00000
# ('Testing Accuracy:', 0.85714287)
# Iter 87360, Minibatch Loss= 18734812.000000, Training Accuracy= 0.95238
# ('Testing Accuracy:', 0.78571427)
# Iter 87780, Minibatch Loss= 234458592.000000, Training Accuracy= 0.95238
# ('Testing Accuracy:', 0.90476191)
# Iter 88200, Minibatch Loss= 0.000000, Training Accuracy= 1.00000
# ('Testing Accuracy:', 0.90476191)
# Iter 88620, Minibatch Loss= 0.000000, Training Accuracy= 1.00000
# ('Testing Accuracy:', 0.88095236)
# Iter 89040, Minibatch Loss= 380883520.000000, Training Accuracy= 0.95238
# ('Testing Accuracy:', 0.69047618)
# Iter 89460, Minibatch Loss= 0.000000, Training Accuracy= 1.00000
# ('Testing Accuracy:', 0.88095236)
# Iter 89880, Minibatch Loss= 0.000000, Training Accuracy= 1.00000
# ('Testing Accuracy:', 0.88095236)
# Iter 90300, Minibatch Loss= 898079424.000000, Training Accuracy= 0.95238
# ('Testing Accuracy:', 0.73809522)
# Iter 90720, Minibatch Loss= 0.000000, Training Accuracy= 1.00000
# ('Testing Accuracy:', 0.85714287)
# Iter 91140, Minibatch Loss= 0.000000, Training Accuracy= 1.00000
# ('Testing Accuracy:', 0.73809522)
# Iter 91560, Minibatch Loss= 0.000000, Training Accuracy= 1.00000
# ('Testing Accuracy:', 0.85714287)
# Iter 91980, Minibatch Loss= 0.000000, Training Accuracy= 1.00000
# ('Testing Accuracy:', 0.78571427)
# Iter 92400, Minibatch Loss= 0.000000, Training Accuracy= 1.00000
# ('Testing Accuracy:', 0.90476191)
# Iter 92820, Minibatch Loss= 0.000000, Training Accuracy= 1.00000
# ('Testing Accuracy:', 0.78571427)
# Iter 93240, Minibatch Loss= 0.000000, Training Accuracy= 1.00000
# ('Testing Accuracy:', 0.78571427)
# Iter 93660, Minibatch Loss= 0.000000, Training Accuracy= 1.00000
# ('Testing Accuracy:', 0.85714287)
# Iter 94080, Minibatch Loss= 767094976.000000, Training Accuracy= 0.95238
# ('Testing Accuracy:', 0.88095236)
# Iter 94500, Minibatch Loss= 0.000000, Training Accuracy= 1.00000
# ('Testing Accuracy:', 0.80952382)
# Iter 94920, Minibatch Loss= 2051771392.000000, Training Accuracy= 0.95238
# ('Testing Accuracy:', 0.78571427)
# Iter 95340, Minibatch Loss= 0.000000, Training Accuracy= 1.00000
# ('Testing Accuracy:', 0.80952382)
# Iter 95760, Minibatch Loss= 1224424576.000000, Training Accuracy= 0.90476
# ('Testing Accuracy:', 0.69047618)
# Iter 96180, Minibatch Loss= 0.000000, Training Accuracy= 1.00000
# ('Testing Accuracy:', 0.88095236)
# Iter 96600, Minibatch Loss= 0.000000, Training Accuracy= 1.00000
# ('Testing Accuracy:', 0.85714287)
# Iter 97020, Minibatch Loss= 164979760.000000, Training Accuracy= 0.95238
# ('Testing Accuracy:', 0.9285714)
# Iter 97440, Minibatch Loss= 0.000000, Training Accuracy= 1.00000
# ('Testing Accuracy:', 0.85714287)
# Iter 97860, Minibatch Loss= 0.000000, Training Accuracy= 1.00000
# ('Testing Accuracy:', 0.83333331)
# Iter 98280, Minibatch Loss= 0.000000, Training Accuracy= 1.00000
# ('Testing Accuracy:', 0.90476191)
# Iter 98700, Minibatch Loss= 0.000000, Training Accuracy= 1.00000
# ('Testing Accuracy:', 0.64285713)
# Iter 99120, Minibatch Loss= 0.000000, Training Accuracy= 1.00000
# ('Testing Accuracy:', 0.88095236)
# Iter 99540, Minibatch Loss= 0.000000, Training Accuracy= 1.00000
# ('Testing Accuracy:', 0.85714287)
# Iter 99960, Minibatch Loss= 0.000000, Training Accuracy= 1.00000
# ('Testing Accuracy:', 0.83333331)
